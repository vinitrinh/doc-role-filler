# %%
import os
os.chdir('..')

# %% [markdown]
# ### 1. Read data

# %%
os.listdir('data/input')
# Out:
# ['cybersecurity-reports', 'muc4']

# %%
import json
from collections import OrderedDict

path = 'data/input/cybersecurity-reports/train_full.json'
with open(path, "r") as doc_keys_file:
    input_roles = json.load(doc_keys_file, object_pairs_hook=OrderedDict)
    
input_roles['fireeye-1']#['doc']
# Out:
# OrderedDict([('doc',
#               'Chinese cyber espionage operators modified the software packages of a legitimate vendor, NetSarang Computer, allowing access to a broad range of industries and institutions that include financial services, transportation, telecommunications, energy, media, academic, retail, and gaming. The malicious actors embedded a backdoor named SHADOWPAD, which can access network data and download additional malware. Based on shared communications infrastructure and similar targeting and tactics, FireEye Threat Intelligence assesses this activity is related to a Chinese espionage team that previously targeted a gaming company in 2015.'),
#              ('roles',
#               OrderedDict([('adversary',
#                             [['Chinese cyber espionage operators',
#                               'malicious actors',
#                               'Chinese espionage team']]),
#                            ('capability', [['backdoor', 'SHADOWPAD']]),
#                            ('infrastructure', []),
#                            ('victim',
#                             [['legitimate vendor,', 'NetSarang Computer'],
#                              ['financial services'],
#                              ['gaming company in 2015']])]))])

# %%
input_roles.copy()
# Out:
# OrderedDict([('fireeye-1',
#               OrderedDict([('doc',
#                             'Chinese cyber espionage operators modified the software packages of a legitimate vendor, NetSarang Computer, allowing access to a broad range of industries and institutions that include financial services, transportation, telecommunications, energy, media, academic, retail, and gaming. The malicious actors embedded a backdoor named SHADOWPAD, which can access network data and download additional malware. Based on shared communications infrastructure and similar targeting and tactics, FireEye Threat Intelligence assesses this activity is related to a Chinese espionage team that previously targeted a gaming company in 2015.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['Chinese cyber espionage operators',
#                                             'malicious actors',
#                                             'Chinese espionage team']]),
#                                          ('capability',
#                                           [['backdoor', 'SHADOWPAD']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['legitimate vendor,',
#                                             'NetSarang Computer'],
#                                            ['financial services'],
#                                            ['gaming company in 2015']])]))])),
#              ('fireeye-2',
#               OrderedDict([('doc',
#                             'GREF Team is an innovative China-nexus cyber espionage operator that focuses on targeting energy, video game development studios, and high-tech companies in the U.S., South Korea, the Netherlands, Italy, France, and Japan. The group leverages a large library of malware tools, compromised digital certificates, and exploits. Besides being linked to a common supplier shared with other Chinese cyber espionage groups, GREF Team is believed to distribute its tools to other distinct China-based actors.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['Chinese cyber espionage groups,',
#                                             'other distinct China-based actors'],
#                                            ['GREF Team', 'GREF Team']]),
#                                          ('capability',
#                                           [['malware tools', 'tools']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-3',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence uncovered GREF Team reusing a sender address from 2016 to target a European cryptocurrency exchange. GREF Team leveraged .NET malware that beacons to an IP address belonging to a South Korean University. This is the first time FireEye Threat Intelligence has uncovered GREF Team targeting financial entities, but it is consistent with our assessment that the team is involved in both financially motivated activity and cyber espionage on behalf of Chinese government interests.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['GREF Team reusing',
#                                             'GREF Team leveraged',
#                                             'GREF Team',
#                                             'the team']]),
#                                          ('capability', [['.NET malware']]),
#                                          ('infrastructure', [['IP address']]),
#                                          ('victim',
#                                           [['South Korean University'],
#                                            ['European cryptocurrency exchange']])]))])),
#              ('fireeye-4',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence analyzed data sourced from a command and control (C&amp;C) server running an application named "Werka," which is used by TrickBot for dynamic webinject administration and delivery. The Werka server delivers unique web injection code based on the presence of different gtags, or campaign identifiers, within requests made to the server. The manner in which this system operates suggests that each gtag value is associated with a different TrickBot customer. FireEye Threat Intelligence has identified and clustered a number of TrickBot gtag values found in the configuration of this system and has further found evidence to suggest that some associated TrickBot customers may be actively using other banking malware families, including Corebot, Danabot, Emotet, Gootkit, IcedID, Nymaim, TinyNuke, Ursnif, and Zeus Panda.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['TrickBot customer',
#                                             'TrickBot customers']]),
#                                          ('capability',
#                                           [['command and control (C&amp;C) server'],
#                                            ['web injection code'],
#                                            ['Danabot'],
#                                            ['IcedID'],
#                                            ['Zeus Panda'],
#                                            ['"Werka,"',
#                                             'TrickBot',
#                                             'Werka server',
#                                             'this system',
#                                             'TrickBot',
#                                             'TrickBot',
#                                             'this system',
#                                             'TrickBot']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-5',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence discovered dozens of irregularities in the domain resolutions of government and commercial websites in the Middle East, North Africa, and Europe. Since 2017, DNS records were altered, and fraudulent Secure Sockets Layer (SSL) certificates were created for more than 100 domains in order to redirect and intercept website traffic and steal valid credentials and emails. FireEye Threat Intelligence has been unable to attribute these unauthorized changes to a tracked group; however, the targeting and limited technical evidence are consistent with Iranian actors. It is also likely that more than one actor has used this technique.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['Iranian actors']]),
#                                          ('capability',
#                                           [['fraudulent Secure Sockets Layer (SSL) certificates']]),
#                                          ('infrastructure',
#                                           [['DNS records'],
#                                            ['website'],
#                                            ['valid credentials and emails']]),
#                                          ('victim', [])]))])),
#              ('fireeye-6',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence has observed evidence of an actor(s) leveraging GitHub to host a variety of malware for campaigns that appear to be targeting entities in Russia for financial gain. Despite recent reporting indicating that these campaigns are distributing Buhtrap, we have not observed direct evidence of Buhtrap payloads being delivered in these operations. We anticipate that this actor(s) will continue conducting operations for at least the near term. However, due to the variety of different malware families these operations have employed, it is possible that this actor(s) will adopt additional malware variants in future operations.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['actor(s)',
#                                             'actor(s)',
#                                             'actor(s)']]),
#                                          ('capability',
#                                           [['Buhtrap', 'Buhtrap payloads']]),
#                                          ('infrastructure', [['GitHub']]),
#                                          ('victim',
#                                           [['entities in Russia']])]))])),
#              ('fireeye-7',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence developed an Operational Technology Cyber Security Incident Ontology (OT-CSIO) to classify different types of attacks, facilitate cross-case analysis, and provide guidance for assessing risks. It consists of high-level analysis and is not meant to provide in-depth insights into the nuances of each incident. Our methodology evaluates four categories, which are target, sophistication, impact, and affected equipment architecture based on the Purdue Model (18-00020979). The OT-CSIO evaluates the full attack lifecycle and does not describe the tactics, techniques, and procedures (TTPs) implemented at each step of the incident.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-8',
#               OrderedDict([('doc',
#                             'Continued examination revealed multiple distinct clusters within the previously reported DNS manipulation activity. Cluster A uses phishing and TWOTONE malware, and Cluster B appears to use web exploits and penetration testing frameworks to gain initial access to victim networks. Actors responsible for Cluster B interrupted operations after an emergency directive was published by the U.S. Department of Homeland Security (DHS) on Jan. 22, 2019, but we cannot definitively say that this publication caused the change in operations. However, FireEye Threat Intelligence discovered Cluster B victims leveraging new infrastructure since then.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['Actors']]),
#                                          ('capability',
#                                           [['DNS manipulation'],
#                                            ['phishing'],
#                                            ['TWOTONE malware']]),
#                                          ('infrastructure',
#                                           [['victim networks']]),
#                                          ('victim', [])]))])),
#              ('fireeye-9',
#               OrderedDict([('doc',
#                             'FireEye devices detected and blocked a likely Iranian group using a compromised email account to target a Lebanese insurance company using TWOTONE malware and newly registered command and control (C&amp;C) infrastructure. The compromised email account belongs to a Lebanese insurance company which experienced DNS hijacking activity Nov. 28, 2018. FireEye Threat Intelligence found a related phishing document impersonating a UK university and domains spoofing an Indian outsourcing firm.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['Iranian group']]),
#                                          ('capability',
#                                           [['TWOTONE malware'],
#                                            ['command and control (C&amp;C) infrastructure'],
#                                            ['phishing document'],
#                                            ['domains spoofing'],
#                                            ['compromised email account',
#                                             'compromised email account']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['UK university'],
#                                            ['Indian outsourcing firm'],
#                                            ['Lebanese insurance company',
#                                             'Lebanese insurance company']])]))])),
#              ('fireeye-10',
#               OrderedDict([('doc',
#                             'In late March 2019, FireEye Threat Intelligence observed UPS- and invoice-themed campaigns delivering Emotet via links leading to ZIP archives containing macro-laden Word documents or JavaScript. This is a departure from its historical tactics, techniques, and procedures (TTPs); most commonly, campaigns have leveraged macro document attachments or links leading to macro documents. FireEye Threat Intelligence also observed changes in the way Emotet communicates through HTTP POST requests with its command and control (C&amp;C) servers. These changes were likely made to evade host and network-based detection mechanisms, although it would be easy for security product vendors to adapt to these changes.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['macro-laden Word documents or JavaScript',
#                                             'macro document attachments',
#                                             'macro documents'],
#                                            ['command and control (C&amp;C) servers'],
#                                            ['Emotet'],
#                                            ['UPS-']]),
#                                          ('infrastructure',
#                                           [['HTTP POST requests']]),
#                                          ('victim', [])]))])),
#              ('fireeye-11',
#               OrderedDict([('doc',
#                             'A supply chain compromise first reported in March 2019 distributed CRACKSHOT and DEADEYE downloaders primarily to victims in Southeast Asia. We surmise the incident is linked to similar previously reported supply chain compromises affecting entities in East Asia, although the tactics, techniques, and procedures (TTPs) demonstrate a greater effort to evade detection and hinder analysis when compared to the older campaigns.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['CRACKSHOT'], ['DEADEYE']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['entities in East Asia']])]))])),
#              ('fireeye-12',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence has been tracking a fast-flux bulletproof hosting infrastructure internally named "Fluxxy" (aka DarkCloud) that has been active since at least late 2009.The actor(s) associated with the bulletproof hosting service use the moniker "Ccweb" and have advertised the bulletproof hosting service on exploit.in since 2010, with the notable addition of fast-flux in 2012. The actor "Sollhost" is believed to be a verified reseller of Fluxxy offering the service under the name of "Sollhost bulletproof hosting." FireEye Threat Intelligence has observed significant interest in Fluxxy by a large number of actors. The related infrastructure has been leveraged for various types of malicious activity, including numerous malware operations, phishing sites, and card shops; we assess with high confidence that actors will continue using this service.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['actor(s)', '"Ccweb"'],
#                                            ['The actor "Sollhost"',
#                                             'Sollhost'],
#                                            ['a large number of actors',
#                                             'actors']]),
#                                          ('capability',
#                                           [['fast-flux bulletproof hosting infrastructure internally',
#                                             'Fluxxy',
#                                             'DarkCloud',
#                                             'the bulletproof hosting service',
#                                             'Fluxxy',
#                                             'Fluxxy'],
#                                            ['malware'],
#                                            ['phishing sites'],
#                                            ['card shops']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-13',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence identified a cluster of activity that began in April 2019 and continued through June 2019 that leveraged web-based attacks including the SharePoint vulnerability CVE-2019-0604 to target financial institutions in Turkey and Southeast Asia. Based on overlaps in infrastructure and targeting, we assess with low confidence this campaign is affiliated with TEMP.Shadow (aka EmpireMonkey) and is likely financially motivated. We anticipate the actors responsible for this operation will continue targeting financial institutions for the foreseeable future; however, the actors may shift at least some tactics, techniques, and procedures (TTPs) in future operations.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['the actors responsible for this operation',
#                                             'the actors']]),
#                                          ('capability',
#                                           [['web-based attacks',
#                                             'SharePoint vulnerability CVE-2019-0604']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['financial institutions in Turkey and Southeast Asia'],
#                                            ['TEMP.Shadow', 'EmpireMonkey'],
#                                            ['financial institutions']])]))])),
#              ('fireeye-15',
#               OrderedDict([('doc',
#                             'Since June 7, 2019, FireEye Threat Intelligence has observed a complete cessation of Emotet-related spam distribution activity. The inactivity of Emotet distribution operations is supported by evidence observed across the FireEye sensor network and active monitoring of the Emotet botnet. The cause for this current cessation of activity is unclear, and it is not known whether this period of inactivity will lead to a permanent change in Emotet operations, though we continue to proactively monitor the situation.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['Emotet distribution operations']]),
#                                          ('capability',
#                                           [['Emotet',
#                                             'Emotet',
#                                             'Emotet botnet',
#                                             'Emotet']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-17',
#               OrderedDict([('doc',
#                             'On May 14, 2019, FireEye devices detected spear-phishing emails attempting to direct victims to Dropbox folders to deliver the TAILCOAT payload. The emails were sent to employees at several European missions to Palestine and related diplomatic entities in the region and leveraged Palestinian-themed lure content. While attribution is unclear, tactics, techniques, and procedures (TTPs) and targeting is consistent with previously reported Molerats Team activity.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['Molerats Team']]),
#                                          ('capability',
#                                           [['spear-phishing emails', 'emails'],
#                                            ['TAILCOAT payload']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['employees at several European missions to Palestine',
#                                             'related diplomatic entities in the region']])]))])),
#              ('fireeye-18',
#               OrderedDict([('doc',
#                             'On July 11, 2019, the Security Service of Ukraine announced the arrest of Mykhailo Rytikov, who they allege has operated a bulletproof hosting service since at least 2007 using the monikers "Whost," "Webhost," and "абдула," among others. FireEye Threat Intelligence observed actors complain that their servers were offline on the date of the arrest, and other actors began questioning whether the Whost username had been taken over by law enforcement. However, forum administrators have since verified the moniker\'s legitimacy, suggesting that at least some individuals behind the Whost service may be continuing to operate. While the arrest of Rytikov may cause a temporary cessation in some malicious activity using Whost, it is unlikely to have a significant impact long-term as actors can easily shift to alternative hosting providers to support their operations.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['Mykhailo Rytikov', 'Rytikov'],
#                                            ['Whost',
#                                             'Webhost',
#                                             'абдула',
#                                             'Whost',
#                                             'Whost']]),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-19',
#               OrderedDict([('doc',
#                             '&nbsp;In June 2019, the National Institute of Standards and Technology (NIST) released a special publication draft that expands the cyber security requirements imposed on certain U.S. Department of Defense (DoD) contractors. The publication includes an explicit requirement to either segment operational technology (OT) or ensure the devices are compliant with imposed cyber security requirements. The inclusion of OT-specific requirements in an information technology (IT)-dominate cyber security standard demonstrates the pertinence of OT and an increased level of awareness by cyber security regulators. We also stress that segmentation is a necessary yet insufficient step toward securing OT networks.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-20',
#               OrderedDict([('doc',
#                             "FireEye Threat Intelligence assesses with moderate confidence that a suspected fabricated letter advocating for the overthrow of the Russian Government, purportedly authored by U.S. Senator Ben Cardin, is being leveraged as part of a broader pro-Russia information operation primarily being run across various Russian and Ukrainian blogs and online forums. While the vast majority of the identified activity is being conducted on forums and blog sites, we have also observed a Reddit account and a small number of suspected inauthentic Facebook accounts promote the activity. The FireEye Threat Intelligence investigation, which has thus far identified activity occurring as recently as July 2, 2019, adds to findings by the Atlantic Council's Digital Forensic Research Lab (DFRLab) published in June 2019, which exposed similar activity occurring in 2018 and early 2019. We assess with high confidence that the broader operation frequently leverages forged correspondence between high-level government officials."),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-21',
#               OrderedDict([('doc',
#                             'On July 12, 2019, FireEye Threat Intelligence identified a phishing campaign that delivered the COOLPANTS backdoor using financial transaction-themed lures. The emails in this campaign included indicators and targeting typical of past suspected TEMP.Splinter campaigns and delivered a COOLPANTS payload that used command and control (C&amp;C) infrastructure overlapping with a past suspected TEMP.MetaStrike campaign. While COOLPANTS is believed to be private to TEMP.MetaStrike, this malware has been delivered in multiple previous campaigns that exhibit delivery methods and targeting characteristic of TEMP.Splinter. Plausible scenarios that may explain this include TEMP.Splinter acting as a delivery service, all observed activity being carried out by TEMP.MetaStrike, or intermittent cooperation between the two groups.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['TEMP.MetaStrike',
#                                             'TEMP.MetaStrike',
#                                             'TEMP.MetaStrike'],
#                                            ['TEMP.Splinter',
#                                             'TEMP.Splinter',
#                                             'TEMP.Splinter']]),
#                                          ('capability',
#                                           [['COOLPANTS backdoor',
#                                             'COOLPANTS payload',
#                                             'COOLPANTS',
#                                             'malware'],
#                                            ['command and control (C&amp;C) infrastructure']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-22',
#               OrderedDict([('doc',
#                             'In May 2019, FireEye devices detected and blocked a spear-phishing campaign likely targeting Ukrainian government entities distributing the ARMEDCLOUD malware attributed to TEMP.Armageddon. Additional samples and related infrastructure were subsequently uncovered. This newest version of ARMEDCLOUD contains anti-forensic features.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['TEMP.Armageddon']]),
#                                          ('capability',
#                                           [['spear-phishing'],
#                                            ['ARMEDCLOUD malware',
#                                             'ARMEDCLOUD'],
#                                            ['anti-forensic features']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['Ukrainian government entities']])]))])),
#              ('fireeye-23',
#               OrderedDict([('doc',
#                             'After a brief cessation of Qakbot activity in early July 2019, FireEye Threat Intelligence observed Qakbot activity resume on July 16 and incorporate an updated version of the password grabber module. The latest version of the password grabber module includes debug strings that reveal names of internal functions and the name of the module itself (plugin_passgrabber).One of the most notable aspects of the update is the inclusion of two embedded URLs that were seen leading to the download of a version of Mimikatz that appears to be unique to Qakbot.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['Qakbot',
#                                             'Qakbot',
#                                             'debug strings',
#                                             'Qakbot'],
#                                            ['password grabber module']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-24',
#               OrderedDict([('doc',
#                             'Beginning on July 18, 2019, FireEye Threat Intelligence observed Amadey campaigns that closely resembled previous Chanitor campaigns and delivered Cobalt Strike Beacon, Pony, SendSafe, and Ursnif. Based on multiple overlaps in the tactics, techniques, and procedures (TTPs) used throughout these campaigns, we have high confidence that at least one of the actors associated with the Chanitor distribution network has begun using AMADEY malware in campaigns as a replacement for Chanitor. While these campaigns appear to be related to prior Chanitor campaigns, there were notable difference beyond its replacement with AMADEY that suggest the actors behind this operation are experimenting with new TTPs.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['actors', 'actors']]),
#                                          ('capability',
#                                           [['Amadey',
#                                             'AMADEY malware',
#                                             'AMADEY'],
#                                            ['Cobalt'],
#                                            ['Pony']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-26',
#               OrderedDict([('doc',
#                             'While overlaps exist in the tools and methodologies used to perform reconnaissance in information technology (IT) and operational technology (OT) environments, the information required for a targeted attack on OT systems is unique. Organizations should identify their unique attack surfaces, the value of their OT information to the adversary, and how the information can be used in the context of a tailored attack. Controlling and protecting this information should be a priority for denying adversary reconnaissance efforts.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure',
#                                           [['information technology (IT) and operational technology (OT) environments',
#                                             'OT systems',
#                                             'OT information']]),
#                                          ('victim', [])]))])),
#              ('fireeye-27',
#               OrderedDict([('doc',
#                             'In late July 2019, FireEye Threat Intelligence observed a campaign using various delivery mechanisms to deliver KAYSLICE and COOLPANTS. Observed recipients included individuals at financial organizations based in Russia and Slovakia. Based on the use of overlapping tactics, techniques, and procedures (TTPs), we assess with moderate confidence that the recent KAYSLICE/COOLPANTS campaign can be attributed to TEMP.MetaStrike (aka Cobalt Group).'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['TEMP.MetaStrike',
#                                             'Cobalt Group']]),
#                                          ('capability',
#                                           [['KAYSLICE and',
#                                             'COOLPANTS.',
#                                             'KAYSLICE/COOLPANTS']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['individuals at financial organizations based in Russia and Slovakia']])]))])),
#              ('fireeye-28',
#               OrderedDict([('doc',
#                             'On July 25, 2019, City Power Johannesburg announced that their information technology (IT) systems were infected with a ransomware virus that encrypted their "databases, applications and networks. " The attack on Johannesburg-based City Power prevented customers on pay-as-you-go plans from purchasing electricity. FireEye Threat Intelligence has recently observed various cases of ransomware infections on IT systems resulting in disruptions or outages to production despite no impact to operational technology (OT) networks (19-00012368). City Power\'s incident is the first instance we have observed where customers lost access to energy as a result of malware infections in corporate networks. We suggest that organizations with high-availability requirements evaluate their safety and business risks related to ransomware attacks.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['ransomware virus',
#                                             'ransomware infections',
#                                             'malware infections',
#                                             'ransomware attacks']]),
#                                          ('infrastructure',
#                                           [['information technology (IT) systems',
#                                             'databases, applications and networks',
#                                             'IT systems',
#                                             'corporate networks']]),
#                                          ('victim',
#                                           [['City Power Johannesburg',
#                                             'Johannesburg-based City Power',
#                                             "City Power's"]])]))])),
#              ('fireeye-29',
#               OrderedDict([('doc',
#                             'Security researchers identified 11 vulnerabilities in the VxWorks real-time operating system (RTOS) developed by Wind River. The collection of vulnerabilities is dubbed "Urgent/11." RTOS have specialized kernels that minimize interruptions to critical system processes. VxWorks is the most common RTOS and can be found in embedded systems used in a wide variety of industries, including aerospace and defense, automotive, consumer electronics, industrial automation, medical devices, and network/computer infrastructure. Asset owners are encouraged to apply the latest patches released by Wind River. Alternative mitigations, such as firewall rules, intrusion detection signatures, or OS-version upgrades, can be deployed as countermeasures in the absence of patches.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['11 vulnerabilities',
#                                             '"Urgent/11."']]),
#                                          ('infrastructure',
#                                           [['critical system processes',
#                                             'embedded systems'],
#                                            ['VxWorks real-time operating system (RTOS)',
#                                             'RTOS',
#                                             'VxWorks is',
#                                             'RTOS']]),
#                                          ('victim', [])]))])),
#              ('fireeye-30',
#               OrderedDict([('doc',
#                             "On July 29, 2019, Capital One announced a data security incident in which an unauthorized actor accessed personal information of over 100 million individuals in the United States and approximately 6 million in Canada who applied for Capital One credit card products between 2005 and early 2019. Paige Adele Thompson, who was arrested in Washington state in association with the breach, exploited a firewall misconfiguration that allowed her to gain access to folders or buckets of data in Capital One's cloud storage space. Currently, the motivation for the attack is uncertain, but the brazenness with which she discussed her activities may suggest that she was at least in part motivated by ego or other factors. The vast amount of data stored in the cloud from many different sources makes systems and data hosted by cloud services providers attractive targets, and we anticipate actors will continue targeting and abusing cloud services for the foreseeable future."),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['unauthorized actor',
#                                             'Paige Adele Thompson',
#                                             'her',
#                                             'she',
#                                             'her',
#                                             'she']]),
#                                          ('capability', []),
#                                          ('infrastructure',
#                                           [['Capital One credit card products'],
#                                            ['firewall misconfiguration'],
#                                            ['cloud storage space']]),
#                                          ('victim',
#                                           [['100 million individuals in the United States'],
#                                            ['6 million in Canada'],
#                                            ['Capital One',
#                                             'Capital One',
#                                             'Capital One']])]))])),
#              ('fireeye-31',
#               OrderedDict([('doc',
#                             'FireEye devices blocked the attempted download of a SOGU payload at a Hong Kong-based media organization. Based on infrastructure overlap and similarities in tactics, techniques, and procedures (TTPs), we believe this activity is likely related to previous Chinese espionage operations leveraging SOGU and HIGHNOON malware. We note that this activity will likely continue in the short to medium term and that media and civil society organizations in the region remain at risk of targeting with SOGU malware.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['Chinese espionage']]),
#                                          ('capability',
#                                           [['HIGHNOON malware'],
#                                            ['SOGU payload',
#                                             'SOGU',
#                                             'SOGU malware.']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['Hong Kong-based media organization'],
#                                            ['media and civil society organizations in the region']])]))])),
#              ('fireeye-32',
#               OrderedDict([('doc',
#                             'In April 2019, FireEye Threat Intelligence reported on a network of suspected inauthentic news sites and social media accounts, aimed at audiences globally, conducting influence activity supportive of the United Arab Emirates (UAE) and critical of its regional rivals, Qatar and Iran. We surmised that the network was being operated by a marketing firm in India on behalf of actors seeking to support UAE political interests. We have continued to identify additional activity that we believe is being conducted by this network, including the leveraging of personas on additional social media platforms to promote political narratives. The personas have promoted narratives, specific to their regions of focus, that reflect UAE political interests. For example, we observed accounts posing as individuals from Turkey promote messaging critical of the Turkish Justice and Development (AKP) party and supportive of Ekrem İmamoğlu, the then-opposition candidate for Istanbul mayor, ahead of the Istanbul mayoral elections that occurred on June 23.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-33',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence uncovered a malicious profiling script on the website of an Armenian think tank in June 2019. The website redirects to a second compromised domain hosting a WITCHCOVEN profiling script. WITCHCOVEN has been used by Russia-nexus Turla since 2014 to collect detailed web browser information and install a persistent tracking cookie. The compromised domain also hosted a sample of the new WHIPSNAP backdoor.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['malicious profiling script',
#                                             'WITCHCOVEN profiling script',
#                                             'WITCHCOVEN'],
#                                            ['persistent tracking cookie'],
#                                            ['WHIPSNAP backdoor']]),
#                                          ('infrastructure',
#                                           [['website',
#                                             'website',
#                                             'compromised domain']]),
#                                          ('victim',
#                                           [['Armenian think tank']])]))])),
#              ('fireeye-34',
#               OrderedDict([('doc',
#                             'FireEye technical analysts examined two APT32 archives leveraging Singapore conference-themed filenames and decoy documents to target unknown victims. At least one sample was hosted on Dropbox and likely delivered through a malicious link embedded in a phishing email. Following victim initialization of the executable contained in the archive, the infection process leads to installation of a FREIGHTBOX dropper and a BEACON payload.'),
#                            ('roles',
#                             OrderedDict([('adversary', [['APT32']]),
#                                          ('capability',
#                                           [['phishing email'],
#                                            ['FREIGHTBOX dropper'],
#                                            ['BEACON payload']]),
#                                          ('infrastructure', [['Dropbox']]),
#                                          ('victim', [])]))])),
#              ('fireeye-36',
#               OrderedDict([('doc',
#                             'FireEye Threat Intelligence analyzed a malicious macro document targeting a U.S.-based water and power utility company in late July 2019. The unknown threat actor leveraged skilled social engineering techniques and LOOKBACK malware. The macro document bears superficial similarities to public FireEye Threat Intelligence reporting on UPPERCUT activity. Entities in the utilities sector are likely at risk of targeting in the short- to medium-term and should remain vigilant.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['The unknown threat actor']]),
#                                          ('capability',
#                                           [['social engineering'],
#                                            ['LOOKBACK malware'],
#                                            ['malicious macro document',
#                                             'macro document'],
#                                            ['UPPERCUT']]),
#                                          ('infrastructure', []),
#                                          ('victim',
#                                           [['Entities in the utilities sector'],
#                                            ['U.S.-based water and power utility company']])]))])),
#              ('fireeye-37',
#               OrderedDict([('doc',
#                             'A newly identified downloader, referred to by FireEye Threat Intelligence as BULLZLINK, demonstrates a number of overlaps with malware developed and offered by badbullzvenom. During July 2019, two campaigns were identified using this downloader, including a NETWIRE campaign attributed to TEMP.Splinter and a likely SQUIDSLEEP/SQUIDGATE campaign that has not yet been attributed to a specific threat actor group. Based upon these observations, we assess with moderate confidence that badbullzvenom is continuing to develop new tools for use by financially motivated threat actors.'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['TEMP.Splinter'], ['actor']]),
#                                          ('capability',
#                                           [['NETWIRE'],
#                                            ['SQUIDSLEEP/SQUIDGATE'],
#                                            ['newly identified downloader',
#                                             'BULLZLINK',
#                                             'this downloader']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('fireeye-38',
#               OrderedDict([('doc',
#                             'In August 2019, FireEye Threat Intelligence identified campaigns leveraging a modified version of SmokeLoader that bypasses the normal SmokeLoader pay-per-update business model. This modified version of the malware has been patched by editing existing binaries to communicate with updated command and control (C&amp;C) URLs. While we have not yet observed any actors publicly advertising this modified version of SmokeLoader for sale, it is plausible that actors could sell this version of the malware for significantly less than the original version of SmokeLoader.'),
# ...
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['open-source remote access tool (RAT)',
#                                             'AhMyth Android RAT',
#                                             'an open-source project software',
#                                             'AhMyth'],
#                                            ['Radio Balouch',
#                                             'RB Music',
#                                             'Radio Balouch']]),
#                                          ('infrastructure',
#                                           [["Google's app-vetting mechanism"],
#                                            ["Android's official apps store"]]),
#                                          ('victim', [['Android users']])]))])),
#              ('bleeping-108',
#               OrderedDict([('doc',
#                             'Multiple versions of the Squid web proxy cache server built with Basic Authentication features are currently vulnerable to code execution and denial-of-service (DoS) attacks triggered by the exploitation of a heap buffer overflow security flaw.\n The vulnerability present in Squid 4.0.23 through 4.7 is caused by incorrect buffer management which renders vulnerable installations to "a heap overflow and possible remote code execution attack when processing HTTP Authentication credentials."\n "When checking Basic Authentication with HttpHeader::getAuth, Squid uses a global buffer to store the decoded data," says MITRE\'s description of the vulnerability. "Squid does not check that the decoded length isn\'t greater than the buffer, leading to a heap-based buffer overflow with user controlled data."\n The flaw was\xa0patched by the web proxy\'s development team with the release of Squid 4.8 on July 9.\n Some unpatched servers exposed to attacks\n'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['denial-of-service (DoS)'],
#                                            ['exploitation of a heap buffer overflow security flaw']]),
#                                          ('infrastructure',
#                                           [['Basic Authentication features'],
#                                            ['Squid web proxy cache server',
#                                             'Squid',
#                                             'Squid',
#                                             'Squid',
#                                             'web proxy',
#                                             'Squid']]),
#                                          ('victim', [])]))])),
#              ('bleeping-109',
#               OrderedDict([('doc',
#                             "Cisco updated the security advisories for three vulnerabilities patched in early August warning customers that its\xa0Product Security Incident Response Team (PSIRT) team is aware of\xa0public exploit code being available.\n Out of the three flaws impacting the Cisco Small Business 220 Series Smart Switches, two are critical remote code execution (CVE-2019-1913) and authentication bypass security (CVE-2019-1912) issues.\n An unauthenticated, remote attacker could take advantage of them to\xa0execute arbitrary code with root privileges and\xa0upload arbitrary files, respectively.\n The third one is a command injection vulnerability tracked as\xa0CVE-2019-1914\xa0and which could potentially enable\xa0authenticated, remote attackers who abuse it to launch a command injection attack.\n As Cisco's updated security advisories explain:\n\nThe Cisco Product Security Incident Response Team (PSIRT) is aware of the existence of public exploit code. Cisco PSIRT is not aware of malicious use of the vulnerability that is described in this advisory.\n\n"),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['An unauthenticated, remote attacker']]),
#                                          ('capability',
#                                           [['command injection attack'],
#                                            ['critical remote code execution'],
#                                            ['authentication bypass security',
#                                             'Cisco PSIRT is']]),
#                                          ('infrastructure',
#                                           [['command injection vulnerability']]),
#                                          ('victim', [])]))])),
#              ('bleeping-110',
#               OrderedDict([('doc',
#                             'Almost 48 hours after security researcher Vasily Kravets (PsiDragon) released his proof of concept (PoC) for a second vulnerability in Steam client for Windows leading to privilege escalation, Valve released a beta update that allegedly fixes the bugs.\n Quick re-cap:\nKravets and another fellow security researcher Matt Nelson\xa0discovered\xa0and responsibly reported a local\xa0privilege\xa0escalation (LPE)\xa0vulnerability that Valve dismissed as being out of scope and would do nothing to mitigate or patch it.\n As a result,\xa0Matt decided to show how the vulnerability could be exploited and published a PoC\xa0where he gets a command prompt window running with\xa0SYSTEM account privileges, the highest for a user on Windows.\n Fast forward a few days and Valve published a patch\xa0for the vulnerability.\xa0 This\xa0was not a complete fix, though,\xa0and could be easily\xa0bypassed; this happened on August 15, when Twitter user\xa0Xiaoyin Liu\xa0posted that they had found a way around the fix.\n\n I found a way to bypass the fix.'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['privilege escalation']]),
#                                          ('infrastructure',
#                                           [['Steam client for Windows']]),
#                                          ('victim',
#                                           [['Valve', 'Valve', 'Valve']])]))])),
#              ('bleeping-112',
#               OrderedDict([('doc',
#                             'Google is adding a built-in data breach notification service to the Chrome browser that will alert\xa0users when they are logging into sites with credentials that have been exposed by breaches.\n With the constant leaks of account credentials from data breaches and the rampant password reuse commonly seen among users, data breach notification services were created to alert users when their email addresses were included in a data breach.\n One of the more popular services is Have I Been Pwned and Mozilla partnered with them to launch a Firefox Monitor service\xa0that is being integrated into the Firefox browser.\n Not to be outdone, Google also recently launched a new data breach service through their\xa0Chrome Password Checkup browser extension, which when installed would alert users if their user names and passwords were compromised when they log\xa0into a site.\n Through the use of the Password Checkup extension, Google conducted a study that estimates 1.5% of all logins have been compromised in data breaches. This study also showed that 26% of users who were shown a data breach notification, changed their password.\n'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure',
#                                           [['credentials',
#                                             'account credentials'],
#                                            ['Firefox Monitor'],
#                                            ['Chrome browser',
#                                             'Firefox browser'],
#                                            ['Password Checkup extension']]),
#                                          ('victim', [])]))])),
#              ('bleeping-113',
#               OrderedDict([('doc',
#                             "Command and control (C2) servers for the Emotet botnet appear to have resumed activity and deliver binaries once more. This comes after being inert since the beginning of June.\n Although it started as a banking trojan in 2014, Emotet changed its course to becoming a botnet that delivers various malware strains.\n Emotet is now one of the top threats, its infrastructure being used to distribute Trickbot, another banking trojan, and then spread the Ryuk ransomware. This combination is dubbed 'triple threat' and has affected public administrations\xa0in the U.S.\n Emotet break is over\n"),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability',
#                                           [['Command and control (C2) servers'],
#                                            ['Emotet botnet',
#                                             'banking trojan',
#                                             'Emotet',
#                                             'Emotet',
#                                             'Emotet'],
#                                            ['malware'],
#                                            ['Trickbot',
#                                             'another banking trojan'],
#                                            ['Ryuk ransomware']]),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))])),
#              ('bleeping-114',
#               OrderedDict([('doc',
#                             'Instagram users are currently targeted by a new phishing campaign that uses login attempt warnings coupled with what looks like two-factor authentication (2FA) codes to make the scam more believable.\n Crooks use phishing\xa0to trick potential victims into handing over\xa0sensitive information via fraudulent websites they control\xa0with the help of a wide range of social engineering techniques, as well as messages designed to look like they\'re sent by someone they know or a legitimate organization.\n In this case, the phishing e-mails distributed by the attackers behind this campaign use fake Instagram login alerts stating that someone attempted to log in to the target\'s account, asking them to confirm their identity via a sign-in page\xa0linked within the message.\n Authentication codes used to add legitimacy\n These messages are designed to look as close as possible to what official messages coming from Instagram to avoid raising any suspicions before the target is redirected to the attackers\' phishing landing page.\n "Apart from a few punctuation errors and the missing space before the word ‘Please’, this message is clean, clear and low-key enough not to raise instant alarm bells," details Sophos\'\xa0Paul Ducklin\xa0who analyzed the campaign.\n'),
#                            ('roles',
#                             OrderedDict([('adversary',
#                                           [['attackers', 'attackers']]),
#                                          ('capability',
#                                           [['social engineering'],
#                                            ['phishing',
#                                             'phishing',
#                                             'phishing e-mails',
#                                             'phishing landing page']]),
#                                          ('infrastructure',
#                                           [['official messages coming from Instagram']]),
#                                          ('victim', [])]))])),
#              ('bleeping-115',
#               OrderedDict([('doc',
#                             'Mastercard disclosed a data breach to the German and Belgian Data Protection Authorities (DPA) involving customer data from the company\'s Priceless Specials loyalty program.\n The\xa0data was made available on the Internet, with customers\' names, payment card numbers, email addresses, home addresses, phone numbers, gender, and dates of birth\xa0being included in the leaked info.\n Mastercard says that "the incident is limited to the Specials program" and that the only payment card information leaked were the numbers of payment cards.\n After the data leak was discovered, Mastercard\xa0suspended the German Priceless Specials\xa0and took down its website, leaving up only a message saying that "This issue has no connection to MasterCard\'s payment network."\n\n "We have received a lot of questions and complaints since the announcement of this incident, we want to reassure users: we have contacted MasterCard in order to get additional information, and are following this case closely together with the Hessian data protection authority and all the other possible concerned authorities," says\xa0David Stevens, Chairman of the Belgian Data Protection Authority.\n Breach discovered after data was leaked\nThe breach was discovered after the loyalty program data was released on the Internet on August 19 says Mastercard.\n'),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure',
#                                           [['email addresses'],
#                                            ['phone numbers'],
#                                            ['home addresses'],
#                                            ['payment card numbers',
#                                             'payment card information'],
#                                            ['website'],
#                                            ["MasterCard's payment network"]]),
#                                          ('victim',
#                                           [['Mastercard',
#                                             'Mastercard',
#                                             'Mastercard',
#                                             'MasterCard',
#                                             'MasterCard',
#                                             'Mastercard']])]))])),
#              ('bleeping-116',
#               OrderedDict([('doc',
#                             "Microsoft says that Bluetooth speakers will stop connecting to\xa0devices running Windows 10, version 1903 after installing the KB4505903 cumulative update released on July 26, 2019.\n Besides the Bluetooth speakers no longer working properly, users will also notice a\xa0Microsoft Bluetooth A2dp Source entry under the\xa0Sound, video and game controllers node displaying a yellow exclamation mark icon in Device Manager.\n This hints at the device being impacted by some\xa0issue related to either missing drivers or the driver not being installed correctly.\n After KB4505903\xa0is installed on a Windows computer with an internal speaker installed, users will experience one of the following issues says Microsoft's support article:\n\n • A Bluetooth speaker can’t connect to the computer.\n • A Bluetooth speaker can connect to the computer."),
#                            ('roles',
#                             OrderedDict([('adversary', []),
#                                          ('capability', []),
#                                          ('infrastructure', []),
#                                          ('victim', [])]))]))])

# %% [markdown]
# ### 2. Load tokenizer and preprocessor

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', use_fast=False)

# this separates the paragraphs into sentences
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import random
from copy import deepcopy
import spacy
from transformers import AutoTokenizer

class Doc_Seq:
    def __init__(self, key, seq_tag_pair, doc):
        self.key = key
        self.seq_tag_pair = seq_tag_pair
        self.doc = doc
    
    def __repr__(self):
        return f'Doc_Seq(key={self.key}, doc={self.doc.text})'

def create_sent_tagging(input_roles, test_set=False, bert_model = 'bert-base-uncased', keys_dict_none_empty=None):
    """
    :param input_roles: ordered dict containing key, doc and roles
    :param test_set: boolean to indicate whether we are processing train or test set
    :param keys_dict_none_empty: list of keys to ignore
    """

    tokenizer = AutoTokenizer.from_pretrained(bert_model, use_fast=False)
    nlp = spacy.load("en_core_web_sm")
    
    doc_keys = deepcopy(input_roles)
    
    # turn doc_keys (entity) into doc_keys (mentions)
    for docid in doc_keys:
        for role in doc_keys[docid]["roles"]:
            mentions = list()
            for entity in doc_keys[docid]["roles"][role]:
                for mention in entity:
                    if mention not in mentions:
                        mentions.append(mention)
            doc_keys[docid]["roles"][role] = mentions

    seqs_all_o = []
    seqs_not_all_o = []
    all_examples = []
    para_lens = []
    # summ = 0
    for key in doc_keys:
        
        # keys to ignore
        if keys_dict_none_empty is not None:
            if key not in keys_dict_none_empty: continue

        # get and sort doc-level spans to extract from doc key
        doc = doc_keys[key]["doc"]
        tags_values = doc_keys[key]["roles"]
        for tag in tags_values:
            values = tags_values[tag]

            values.sort(key=lambda x: len(x) *(-1)) # longest first
            # values.sort(key=lambda x: len(x))     # shortest first

        # sample tag_values
        # OrderedDict([('perp_individual_id', ['TERRORISTS', 'TERRORIST']), 
        # ('perp_organization_id', ['FARABUNDO MARTI NATIONAL LIBERATION FRONT', 'MARTI NATIONAL', 'FMLN']),
        # ('phys_tgt_id', ['LAS CANAS BRIDGE']), ('hum_tgt_name', []), 
        # ('incident_instrument_id', ['MORTAR', 'RIFLE'])])

        # get all the sentences from this doc key
        # JT: Split the documents by paragraphs
        paragraphs = doc.split("\n\n")
        doc_sents = []
        for para in paragraphs:
            para2 = " ".join(para.split("\n"))#.lower()
            para2 = nlp(para2)
            cnt = 0
            for sent in para2.sents:
                cnt += 1
                doc_sents.append(sent.text)
            para_lens.append(cnt)


        # get seqs and annotate
        # JT: Split long paragraphs by sentences
        num_sent_to_include = 3
        for idx in range(len(doc_sents)):
            if test_set:
                start = idx * num_sent_to_include
            else:
                start = idx
            end = start + num_sent_to_include
            if start >= len(doc_sents): break

            if end > len(doc_sents): end = len(doc_sents)

            # JT: sequence is a long string of the paragraph
            sequence = " ".join(doc_sents[start: end])
            
            all_o = True
            seq_tag_pair = []
            spacy_doc = nlp(sequence.lower())
            for tok in spacy_doc:
                # JT: my own modification to keep track of spacy tokens
                subword_tokens = tokenizer.tokenize(tok.text)
                for subword_token in subword_tokens:
                    seq_tag_pair.append([subword_token, 'O', tok.i])
            # seq_tokenized = tokenizer.tokenize(sequence)
            # seq_tag_pair = [[token, 'O'] for token in seq_tokenized]
            
            # JT: this iterates through the roles
            for tag_anno in tags_values:
                values = tags_values[tag_anno]
                for value in values:
                    value_tokenized = tokenizer.tokenize(value)
                    for idx, token_tag in enumerate(seq_tag_pair):
                        token, tag, word_idx = token_tag[0], token_tag[1], token_tag[2]
                        if token == value_tokenized[0]:
                            start, end = idx, idx + len(value_tokenized)
                            if end <= len(seq_tag_pair):
                                candidate = [x[0] for x in seq_tag_pair[start: end]]
                                tags = [x[1] for x in seq_tag_pair[start: end]] 

                                already_annoted = False
                                for tag in tags: 
                                    if tag != 'O': already_annoted = True
                                if already_annoted: continue

                                if " ".join(candidate) == " ".join(value_tokenized):
                                    all_o = False
                                    seq_tag_pair[start][1] = "B-" + tag_anno
                                    for i in range(start + 1, end):
                                        seq_tag_pair[i][1] = "I-" + tag_anno

            example = {'doc_id':key, 'seq': seq_tag_pair, 'text':sequence}
            # example = doc(key, seq_tag_pair, spacy_doc)
            all_examples.append(example)
            if not all_o:
                seqs_not_all_o.append(example)
            else:
                seqs_all_o.append(example)
            print(seq_tag_pair)

    # print(seqs_all_o, len(seqs_not_all_o))
    seqs_all_o_sample = random.sample(seqs_all_o, min(len(seqs_not_all_o), len(seqs_all_o)) )
    all_examples_sample_neg = seqs_not_all_o + seqs_all_o_sample
    print("Average paragraph sent # :", sum(para_lens)/len(para_lens))

    return all_examples_sample_neg, all_examples
    
all_examples_sample_neg, all_examples = create_sent_tagging(input_roles)
# Out:
# [['chinese', 'B-adversary', 0], ['cyber', 'I-adversary', 1], ['espionage', 'I-adversary', 2], ['operators', 'I-adversary', 3], ['modified', 'O', 4], ['the', 'O', 5], ['software', 'O', 6], ['packages', 'O', 7], ['of', 'O', 8], ['a', 'O', 9], ['legitimate', 'B-victim', 10], ['vendor', 'I-victim', 11], [',', 'I-victim', 12], ['nets', 'B-victim', 13], ['##aran', 'I-victim', 13], ['##g', 'I-victim', 13], ['computer', 'I-victim', 14], [',', 'O', 15], ['allowing', 'O', 16], ['access', 'O', 17], ['to', 'O', 18], ['a', 'O', 19], ['broad', 'O', 20], ['range', 'O', 21], ['of', 'O', 22], ['industries', 'O', 23], ['and', 'O', 24], ['institutions', 'O', 25], ['that', 'O', 26], ['include', 'O', 27], ['financial', 'B-victim', 28], ['services', 'I-victim', 29], [',', 'O', 30], ['transportation', 'O', 31], [',', 'O', 32], ['telecommunications', 'O', 33], [',', 'O', 34], ['energy', 'O', 35], [',', 'O', 36], ['media', 'O', 37], [',', 'O', 38], ['academic', 'O', 39], [',', 'O', 40], ['retail', 'O', 41], [',', 'O', 42], ['and', 'O', 43], ['gaming', 'O', 44], ['.', 'O', 45], ['the', 'O', 46], ['malicious', 'B-adversary', 47], ['actors', 'I-adversary', 48], ['embedded', 'O', 49], ['a', 'O', 50], ['back', 'B-capability', 51], ['##door', 'I-capability', 51], ['named', 'O', 52], ['shadow', 'B-capability', 53], ['##pad', 'I-capability', 53], [',', 'O', 54], ['which', 'O', 55], ['can', 'O', 56], ['access', 'O', 57], ['network', 'O', 58], ['data', 'O', 59], ['and', 'O', 60], ['download', 'O', 61], ['additional', 'O', 62], ['mal', 'O', 63], ['##ware', 'O', 63], ['.', 'O', 64], ['based', 'O', 65], ['on', 'O', 66], ['shared', 'O', 67], ['communications', 'O', 68], ['infrastructure', 'O', 69], ['and', 'O', 70], ['similar', 'O', 71], ['targeting', 'O', 72], ['and', 'O', 73], ['tactics', 'O', 74], [',', 'O', 75], ['fire', 'O', 76], ['##eye', 'O', 76], ['threat', 'O', 77], ['intelligence', 'O', 78], ['assess', 'O', 79], ['##es', 'O', 79], ['this', 'O', 80], ['activity', 'O', 81], ['is', 'O', 82], ['related', 'O', 83], ['to', 'O', 84], ['a', 'O', 85], ['chinese', 'B-adversary', 86], ['espionage', 'I-adversary', 87], ['team', 'I-adversary', 88], ['that', 'O', 89], ['previously', 'O', 90], ['targeted', 'O', 91], ['a', 'O', 92], ['gaming', 'B-victim', 93], ['company', 'I-victim', 94], ['in', 'I-victim', 95], ['2015', 'I-victim', 96], ['.', 'O', 97]]
# %%
all_examples[:3]
# Out:
# [{'doc_id': 'fireeye-1',
#   'seq': [['chinese', 'B-adversary', 0],
#    ['cyber', 'I-adversary', 1],
#    ['espionage', 'I-adversary', 2],
#    ['operators', 'I-adversary', 3],
#    ['modified', 'O', 4],
#    ['the', 'O', 5],
#    ['software', 'O', 6],
#    ['packages', 'O', 7],
#    ['of', 'O', 8],
#    ['a', 'O', 9],
#    ['legitimate', 'B-victim', 10],
#    ['vendor', 'I-victim', 11],
#    [',', 'I-victim', 12],
#    ['nets', 'B-victim', 13],
#    ['##aran', 'I-victim', 13],
#    ['##g', 'I-victim', 13],
#    ['computer', 'I-victim', 14],
#    [',', 'O', 15],
#    ['allowing', 'O', 16],
#    ['access', 'O', 17],
#    ['to', 'O', 18],
#    ['a', 'O', 19],
#    ['broad', 'O', 20],
#    ['range', 'O', 21],
#    ['of', 'O', 22],
#    ['industries', 'O', 23],
#    ['and', 'O', 24],
#    ['institutions', 'O', 25],
#    ['that', 'O', 26],
#    ['include', 'O', 27],
#    ['financial', 'B-victim', 28],
#    ['services', 'I-victim', 29],
#    [',', 'O', 30],
#    ['transportation', 'O', 31],
#    [',', 'O', 32],
#    ['telecommunications', 'O', 33],
#    [',', 'O', 34],
#    ['energy', 'O', 35],
#    [',', 'O', 36],
#    ['media', 'O', 37],
#    [',', 'O', 38],
#    ['academic', 'O', 39],
#    [',', 'O', 40],
#    ['retail', 'O', 41],
#    [',', 'O', 42],
#    ['and', 'O', 43],
#    ['gaming', 'O', 44],
#    ['.', 'O', 45],
#    ['the', 'O', 46],
#    ['malicious', 'B-adversary', 47],
#    ['actors', 'I-adversary', 48],
#    ['embedded', 'O', 49],
#    ['a', 'O', 50],
#    ['back', 'B-capability', 51],
#    ['##door', 'I-capability', 51],
#    ['named', 'O', 52],
#    ['shadow', 'B-capability', 53],
#    ['##pad', 'I-capability', 53],
#    [',', 'O', 54],
#    ['which', 'O', 55],
#    ['can', 'O', 56],
#    ['access', 'O', 57],
#    ['network', 'O', 58],
#    ['data', 'O', 59],
#    ['and', 'O', 60],
#    ['download', 'O', 61],
#    ['additional', 'O', 62],
#    ['mal', 'O', 63],
#    ['##ware', 'O', 63],
#    ['.', 'O', 64],
#    ['based', 'O', 65],
#    ['on', 'O', 66],
#    ['shared', 'O', 67],
#    ['communications', 'O', 68],
#    ['infrastructure', 'O', 69],
#    ['and', 'O', 70],
#    ['similar', 'O', 71],
#    ['targeting', 'O', 72],
#    ['and', 'O', 73],
#    ['tactics', 'O', 74],
#    [',', 'O', 75],
#    ['fire', 'O', 76],
#    ['##eye', 'O', 76],
#    ['threat', 'O', 77],
#    ['intelligence', 'O', 78],
#    ['assess', 'O', 79],
#    ['##es', 'O', 79],
#    ['this', 'O', 80],
#    ['activity', 'O', 81],
#    ['is', 'O', 82],
#    ['related', 'O', 83],
#    ['to', 'O', 84],
#    ['a', 'O', 85],
#    ['chinese', 'B-adversary', 86],
#    ['espionage', 'I-adversary', 87],
#    ['team', 'I-adversary', 88],
#    ['that', 'O', 89],
#    ['previously', 'O', 90],
#    ['targeted', 'O', 91],
#    ['a', 'O', 92],
#    ['gaming', 'B-victim', 93],
#    ['company', 'I-victim', 94],
#    ['in', 'I-victim', 95],
#    ['2015', 'I-victim', 96],
#    ['.', 'O', 97]],
#   'text': 'Chinese cyber espionage operators modified the software packages of a legitimate vendor, NetSarang Computer, allowing access to a broad range of industries and institutions that include financial services, transportation, telecommunications, energy, media, academic, retail, and gaming. The malicious actors embedded a backdoor named SHADOWPAD, which can access network data and download additional malware. Based on shared communications infrastructure and similar targeting and tactics, FireEye Threat Intelligence assesses this activity is related to a Chinese espionage team that previously targeted a gaming company in 2015.'},
#  {'doc_id': 'fireeye-1',
#   'seq': [['the', 'O', 0],
#    ['malicious', 'B-adversary', 1],
#    ['actors', 'I-adversary', 2],
#    ['embedded', 'O', 3],
#    ['a', 'O', 4],
#    ['back', 'B-capability', 5],
#    ['##door', 'I-capability', 5],
#    ['named', 'O', 6],
#    ['shadow', 'B-capability', 7],
#    ['##pad', 'I-capability', 7],
#    [',', 'O', 8],
#    ['which', 'O', 9],
#    ['can', 'O', 10],
#    ['access', 'O', 11],
#    ['network', 'O', 12],
#    ['data', 'O', 13],
#    ['and', 'O', 14],
#    ['download', 'O', 15],
#    ['additional', 'O', 16],
#    ['mal', 'O', 17],
#    ['##ware', 'O', 17],
#    ['.', 'O', 18],
#    ['based', 'O', 19],
#    ['on', 'O', 20],
#    ['shared', 'O', 21],
#    ['communications', 'O', 22],
#    ['infrastructure', 'O', 23],
#    ['and', 'O', 24],
#    ['similar', 'O', 25],
#    ['targeting', 'O', 26],
#    ['and', 'O', 27],
#    ['tactics', 'O', 28],
#    [',', 'O', 29],
#    ['fire', 'O', 30],
#    ['##eye', 'O', 30],
#    ['threat', 'O', 31],
#    ['intelligence', 'O', 32],
#    ['assess', 'O', 33],
#    ['##es', 'O', 33],
#    ['this', 'O', 34],
#    ['activity', 'O', 35],
#    ['is', 'O', 36],
#    ['related', 'O', 37],
#    ['to', 'O', 38],
#    ['a', 'O', 39],
#    ['chinese', 'B-adversary', 40],
#    ['espionage', 'I-adversary', 41],
#    ['team', 'I-adversary', 42],
#    ['that', 'O', 43],
#    ['previously', 'O', 44],
#    ['targeted', 'O', 45],
#    ['a', 'O', 46],
#    ['gaming', 'B-victim', 47],
#    ['company', 'I-victim', 48],
#    ['in', 'I-victim', 49],
#    ['2015', 'I-victim', 50],
#    ['.', 'O', 51]],
#   'text': 'The malicious actors embedded a backdoor named SHADOWPAD, which can access network data and download additional malware. Based on shared communications infrastructure and similar targeting and tactics, FireEye Threat Intelligence assesses this activity is related to a Chinese espionage team that previously targeted a gaming company in 2015.'},
#  {'doc_id': 'fireeye-1',
#   'seq': [['based', 'O', 0],
#    ['on', 'O', 1],
#    ['shared', 'O', 2],
#    ['communications', 'O', 3],
#    ['infrastructure', 'O', 4],
#    ['and', 'O', 5],
#    ['similar', 'O', 6],
#    ['targeting', 'O', 7],
#    ['and', 'O', 8],
#    ['tactics', 'O', 9],
#    [',', 'O', 10],
#    ['fire', 'O', 11],
#    ['##eye', 'O', 11],
#    ['threat', 'O', 12],
#    ['intelligence', 'O', 13],
#    ['assess', 'O', 14],
#    ['##es', 'O', 14],
#    ['this', 'O', 15],
#    ['activity', 'O', 16],
#    ['is', 'O', 17],
#    ['related', 'O', 18],
#    ['to', 'O', 19],
#    ['a', 'O', 20],
#    ['chinese', 'B-adversary', 21],
#    ['espionage', 'I-adversary', 22],
#    ['team', 'I-adversary', 23],
#    ['that', 'O', 24],
#    ['previously', 'O', 25],
#    ['targeted', 'O', 26],
#    ['a', 'O', 27],
#    ['gaming', 'B-victim', 28],
#    ['company', 'I-victim', 29],
#    ['in', 'I-victim', 30],
#    ['2015', 'I-victim', 31],
#    ['.', 'O', 32]],
#   'text': 'Based on shared communications infrastructure and similar targeting and tactics, FireEye Threat Intelligence assesses this activity is related to a Chinese espionage team that previously targeted a gaming company in 2015.'}]

# %% [markdown]
# ### Test function

# %%
import os
os.chdir('..')

import json
from collections import OrderedDict

path = 'data/input/cybersecurity-reports/train_full.json'
with open(path, "r") as doc_keys_file:
    input_roles = json.load(doc_keys_file, object_pairs_hook=OrderedDict)
    
input_roles['fireeye-1']#['doc']

from src.preprocessing import create_sent_tagging
all_examples_sample_neg, all_examples = create_sent_tagging(input_roles)
all_examples_sample_neg[:3]
# Out:
# Average paragraph sent # : 3.515695067264574
# [{'doc_id': 'fireeye-1',
#   'seq': [['chinese', 'B-adversary', 0],
#    ['cyber', 'I-adversary', 1],
#    ['espionage', 'I-adversary', 2],
#    ['operators', 'I-adversary', 3],
#    ['modified', 'O', 4],
#    ['the', 'O', 5],
#    ['software', 'O', 6],
#    ['packages', 'O', 7],
#    ['of', 'O', 8],
#    ['a', 'O', 9],
#    ['legitimate', 'B-victim', 10],
#    ['vendor', 'I-victim', 11],
#    [',', 'I-victim', 12],
#    ['nets', 'B-victim', 13],
#    ['##aran', 'I-victim', 13],
#    ['##g', 'I-victim', 13],
#    ['computer', 'I-victim', 14],
#    [',', 'O', 15],
#    ['allowing', 'O', 16],
#    ['access', 'O', 17],
#    ['to', 'O', 18],
#    ['a', 'O', 19],
#    ['broad', 'O', 20],
#    ['range', 'O', 21],
#    ['of', 'O', 22],
#    ['industries', 'O', 23],
#    ['and', 'O', 24],
#    ['institutions', 'O', 25],
#    ['that', 'O', 26],
#    ['include', 'O', 27],
#    ['financial', 'B-victim', 28],
#    ['services', 'I-victim', 29],
#    [',', 'O', 30],
#    ['transportation', 'O', 31],
#    [',', 'O', 32],
#    ['telecommunications', 'O', 33],
#    [',', 'O', 34],
#    ['energy', 'O', 35],
#    [',', 'O', 36],
#    ['media', 'O', 37],
#    [',', 'O', 38],
#    ['academic', 'O', 39],
#    [',', 'O', 40],
#    ['retail', 'O', 41],
#    [',', 'O', 42],
#    ['and', 'O', 43],
#    ['gaming', 'O', 44],
#    ['.', 'O', 45],
#    ['the', 'O', 46],
#    ['malicious', 'B-adversary', 47],
#    ['actors', 'I-adversary', 48],
#    ['embedded', 'O', 49],
#    ['a', 'O', 50],
#    ['back', 'B-capability', 51],
#    ['##door', 'I-capability', 51],
#    ['named', 'O', 52],
#    ['shadow', 'B-capability', 53],
#    ['##pad', 'I-capability', 53],
#    [',', 'O', 54],
#    ['which', 'O', 55],
#    ['can', 'O', 56],
#    ['access', 'O', 57],
#    ['network', 'O', 58],
#    ['data', 'O', 59],
#    ['and', 'O', 60],
#    ['download', 'O', 61],
#    ['additional', 'O', 62],
#    ['mal', 'O', 63],
#    ['##ware', 'O', 63],
#    ['.', 'O', 64],
#    ['based', 'O', 65],
#    ['on', 'O', 66],
#    ['shared', 'O', 67],
#    ['communications', 'O', 68],
#    ['infrastructure', 'O', 69],
#    ['and', 'O', 70],
#    ['similar', 'O', 71],
#    ['targeting', 'O', 72],
#    ['and', 'O', 73],
#    ['tactics', 'O', 74],
#    [',', 'O', 75],
#    ['fire', 'O', 76],
#    ['##eye', 'O', 76],
#    ['threat', 'O', 77],
#    ['intelligence', 'O', 78],
#    ['assess', 'O', 79],
#    ['##es', 'O', 79],
#    ['this', 'O', 80],
#    ['activity', 'O', 81],
#    ['is', 'O', 82],
#    ['related', 'O', 83],
#    ['to', 'O', 84],
#    ['a', 'O', 85],
#    ['chinese', 'B-adversary', 86],
#    ['espionage', 'I-adversary', 87],
#    ['team', 'I-adversary', 88],
#    ['that', 'O', 89],
#    ['previously', 'O', 90],
#    ['targeted', 'O', 91],
#    ['a', 'O', 92],
#    ['gaming', 'B-victim', 93],
#    ['company', 'I-victim', 94],
#    ['in', 'I-victim', 95],
#    ['2015', 'I-victim', 96],
#    ['.', 'O', 97]],
#   'text': 'chinese cyber espionage operators modified the software packages of a legitimate vendor, netsarang computer, allowing access to a broad range of industries and institutions that include financial services, transportation, telecommunications, energy, media, academic, retail, and gaming. the malicious actors embedded a backdoor named shadowpad, which can access network data and download additional malware. based on shared communications infrastructure and similar targeting and tactics, fireeye threat intelligence assesses this activity is related to a chinese espionage team that previously targeted a gaming company in 2015.'},
#  {'doc_id': 'fireeye-1',
#   'seq': [['the', 'O', 0],
#    ['malicious', 'B-adversary', 1],
#    ['actors', 'I-adversary', 2],
#    ['embedded', 'O', 3],
#    ['a', 'O', 4],
#    ['back', 'B-capability', 5],
#    ['##door', 'I-capability', 5],
#    ['named', 'O', 6],
#    ['shadow', 'B-capability', 7],
#    ['##pad', 'I-capability', 7],
#    [',', 'O', 8],
#    ['which', 'O', 9],
#    ['can', 'O', 10],
#    ['access', 'O', 11],
#    ['network', 'O', 12],
#    ['data', 'O', 13],
#    ['and', 'O', 14],
#    ['download', 'O', 15],
#    ['additional', 'O', 16],
#    ['mal', 'O', 17],
#    ['##ware', 'O', 17],
#    ['.', 'O', 18],
#    ['based', 'O', 19],
#    ['on', 'O', 20],
#    ['shared', 'O', 21],
#    ['communications', 'O', 22],
#    ['infrastructure', 'O', 23],
#    ['and', 'O', 24],
#    ['similar', 'O', 25],
#    ['targeting', 'O', 26],
#    ['and', 'O', 27],
#    ['tactics', 'O', 28],
#    [',', 'O', 29],
#    ['fire', 'O', 30],
#    ['##eye', 'O', 30],
#    ['threat', 'O', 31],
#    ['intelligence', 'O', 32],
#    ['assess', 'O', 33],
#    ['##es', 'O', 33],
#    ['this', 'O', 34],
#    ['activity', 'O', 35],
#    ['is', 'O', 36],
#    ['related', 'O', 37],
#    ['to', 'O', 38],
#    ['a', 'O', 39],
#    ['chinese', 'B-adversary', 40],
#    ['espionage', 'I-adversary', 41],
#    ['team', 'I-adversary', 42],
#    ['that', 'O', 43],
#    ['previously', 'O', 44],
#    ['targeted', 'O', 45],
#    ['a', 'O', 46],
#    ['gaming', 'B-victim', 47],
#    ['company', 'I-victim', 48],
#    ['in', 'I-victim', 49],
#    ['2015', 'I-victim', 50],
#    ['.', 'O', 51]],
#   'text': 'the malicious actors embedded a backdoor named shadowpad, which can access network data and download additional malware. based on shared communications infrastructure and similar targeting and tactics, fireeye threat intelligence assesses this activity is related to a chinese espionage team that previously targeted a gaming company in 2015.'},
#  {'doc_id': 'fireeye-1',
#   'seq': [['based', 'O', 0],
#    ['on', 'O', 1],
#    ['shared', 'O', 2],
#    ['communications', 'O', 3],
#    ['infrastructure', 'O', 4],
#    ['and', 'O', 5],
#    ['similar', 'O', 6],
#    ['targeting', 'O', 7],
#    ['and', 'O', 8],
#    ['tactics', 'O', 9],
#    [',', 'O', 10],
#    ['fire', 'O', 11],
#    ['##eye', 'O', 11],
#    ['threat', 'O', 12],
#    ['intelligence', 'O', 13],
#    ['assess', 'O', 14],
#    ['##es', 'O', 14],
#    ['this', 'O', 15],
#    ['activity', 'O', 16],
#    ['is', 'O', 17],
#    ['related', 'O', 18],
#    ['to', 'O', 19],
#    ['a', 'O', 20],
#    ['chinese', 'B-adversary', 21],
#    ['espionage', 'I-adversary', 22],
#    ['team', 'I-adversary', 23],
#    ['that', 'O', 24],
#    ['previously', 'O', 25],
#    ['targeted', 'O', 26],
#    ['a', 'O', 27],
#    ['gaming', 'B-victim', 28],
#    ['company', 'I-victim', 29],
#    ['in', 'I-victim', 30],
#    ['2015', 'I-victim', 31],
#    ['.', 'O', 32]],
#   'text': 'based on shared communications infrastructure and similar targeting and tactics, fireeye threat intelligence assesses this activity is related to a chinese espionage team that previously targeted a gaming company in 2015.'}]

# %% [markdown]
# ### Preprocess all files

# %%
path = "data/input/cybersecurity-reports/"
filenames = ['dev_full.json', 'test.json', 'train_full.json']

# %%
for filename in filenames:
    with open(path + filename, "r") as doc_keys_file:
        input_roles = json.load(doc_keys_file, object_pairs_hook=OrderedDict)

    from src.preprocessing import create_sent_tagging
    all_examples_sample_neg, all_examples = create_sent_tagging(input_roles)
    
    # writing to jsonlines file
    with open('data/processed/' + filename+'l', 'a', encoding='utf-8') as f:
        for line in all_examples_sample_neg:
            f.write(json.dumps(line, ensure_ascii=False) + '\n')
# Out:
# Average paragraph sent # : 3.6363636363636362
# Average paragraph sent # : 3.090909090909091
# Average paragraph sent # : 3.515695067264574
